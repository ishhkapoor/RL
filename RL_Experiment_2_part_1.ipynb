# %% [markdown]
# <a href="https://colab.research.google.com/github/ishhkapoor/RL/blob/main/RL_Experiment_2_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import numpy as np
# 10 random integers b/w 0 and 50
x = np.random.randint(0,50,100)
x
# Out:
# array([48, 28, 15, 39, 33, 32, 44, 23,  7, 17,  5, 15, 33, 40,  0, 30, 26,
#        35, 26, 25, 11, 14,  1, 43, 46, 18, 23, 29, 12, 37, 49, 48, 20, 47,
#        28, 18, 22, 31, 26,  0, 29, 41, 44, 49, 42, 12, 28, 48, 39, 14, 24,
#        33,  9, 39, 39,  0, 12, 41, 17, 35, 32, 20, 18,  4, 38, 41, 13,  6,
#        28, 32, 10, 39, 31, 20, 38, 22,  7, 32, 31, 15,  7,  1, 14, 38, 13,
#        45, 44, 16,  6,  6, 17, 30, 28, 28, 46, 20,  8, 36,  7, 45])

# %%
import numpy as np
#positive correlation with some noise
y = x + np.random.normal(0,10,100)
y
# Out:
# array([49.95808921, 26.22547108,  5.23405769, 43.08534934, 40.68954012,
#        37.05232212, 54.71665704, 14.86777386,  5.7602912 , 19.61824801,
#         4.25149217,  6.75058493, 26.30802551, 48.6995574 , -3.61565945,
#        33.14401817, 35.13492016, 32.74879496, 19.38654681, 36.59734245,
#        26.64425694,  5.00250649, -2.95911066, 34.28229855, 33.38199764,
#        26.12424055, 20.72747273,  9.72911134,  4.30567397, 39.04225405,
#        35.05028571, 59.11743453, 18.73783594, 61.59715498, 36.30630336,
#        17.3002553 , 13.94838403, 29.88214081, 33.45329354, -3.19661759,
#        21.13881179, 24.34481071, 36.78737296, 56.15960351, 50.06542382,
#         7.93510176, 20.83951284, 45.03988159, 39.9317121 , 17.29679433,
#        30.60871675, 20.19237049, -0.52619135, 36.0740986 , 47.18510113,
#        11.90891826, -4.47303383, 51.28948368, 25.03481092, 37.84628004,
#        45.75539802, 14.19533449, 10.42618707,  8.31357951, 39.06031983,
# ...

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use("ggplot")

plt.scatter(x,y)
plt.show()

#zero correlation

# %%
import numpy as np
# 1000 random integers b/w 0 and 50
x = np.random.randint(0,50,1000)
x
# Out:
# array([39, 26, 14,  9, 35, 26,  5, 47, 18, 17,  3, 10, 27, 40, 43, 45,  1,
#        31,  1, 13, 37, 11, 38, 30,  4, 15, 26, 45, 43, 48, 39, 10, 48, 47,
#        36,  9, 49, 46, 24, 33,  6, 30, 44,  1, 25, 32, 17, 29, 37, 43, 38,
#        43, 22, 33, 45, 15, 38,  6, 18, 18,  5, 39, 17,  8, 15,  1, 32,  7,
#         3, 10, 45,  2, 22,  2, 41, 33, 47, 37, 13, 36,  2, 39, 32, 21, 12,
#         6, 42, 49, 29, 11,  6,  7, 15, 12, 18, 19, 36, 41, 42, 31, 45, 31,
#         0, 16,  7,  9, 23, 41, 35, 38, 37, 21, 11, 20,  5, 34, 19, 34, 16,
#        27, 31, 14, 27, 36,  6, 23, 29, 32, 48, 27, 21, 13, 30, 24, 14, 24,
#        26, 34,  6,  3, 26, 13,  3, 45, 30, 48, 33, 46, 35, 28, 25, 26, 33,
#        47, 45, 40,  9, 37, 30, 39, 40, 17,  1, 30, 35,  8, 19, 18,  7, 16,
#         7,  7, 34, 24, 18, 17, 35, 46, 29, 33, 36, 34, 15, 43, 49,  7,  0,
#         8,  1, 39,  2, 28, 33, 35, 37, 44, 14, 46, 20, 45, 17, 28, 17, 24,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82955951],
#        [0.82955951, 1.        ]])

# %%
z = 100-x
z
# Out:
# array([ 52,  72,  85,  61,  67,  68,  56,  77,  93,  83,  95,  85,  67,
#         60, 100,  70,  74,  65,  74,  75,  89,  86,  99,  57,  54,  82,
#         77,  71,  88,  63,  51,  52,  80,  53,  72,  82,  78,  69,  74,
#        100,  71,  59,  56,  51,  58,  88,  72,  52,  61,  86,  76,  67,
#         91,  61,  61, 100,  88,  59,  83,  65,  68,  80,  82,  96,  62,
#         59,  87,  94,  72,  68,  90,  61,  69,  80,  62,  78,  93,  68,
#         69,  85,  93,  99,  86,  62,  87,  55,  56,  84,  94,  94,  83,
#         70,  72,  72,  54,  80,  92,  64,  93,  55])

# %%
np.corrcoef(x,z)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use("ggplot")

plt.scatter(x,z)
plt.show()

# %%
import numpy as np
# 1000 random integers b/w 0 and 50
p = np.random.randint(0,100,1000)
p
# Out:
# array([57, 92, 36,  2, 93, 73,  7,  0, 45, 70, 44, 80, 77, 94, 90,  7, 31,
#        16, 36, 59,  3, 30, 17, 51, 89, 94, 83, 71, 66, 46, 27, 49, 50, 73,
#        38,  8, 16, 11, 49, 99, 40, 68, 66, 71, 62, 22, 52, 52, 85, 66, 79,
#        94, 86, 69, 23, 74, 70, 60, 79, 76, 98, 22, 87,  5, 50, 63, 61, 24,
#        72, 40, 40, 57, 75,  9, 97, 97, 45,  4, 64, 49, 79, 79, 91, 88, 59,
#        81, 83, 16, 45, 55, 77, 93, 78, 67,  1,  5, 43, 48, 20, 18, 21, 75,
#        10, 62, 35, 74, 48, 72, 53, 49, 75, 51, 65, 85, 93, 16, 40, 48, 51,
#        84, 47, 61, 88, 95, 35, 15, 32, 90,  7, 92, 67, 18, 27, 37, 48, 74,
#        61, 71, 63, 57, 24, 67, 44, 61, 98, 71, 99,  1, 82, 27, 54,  4,  6,
#        57, 23, 50, 73, 27, 22, 61, 91, 75, 44,  2,  4, 95, 25, 11, 49, 80,
#        51, 18, 80, 51, 67, 32, 81, 65, 48, 90, 79, 18,  3, 96, 65, 88, 60,
#        10, 65, 55, 14, 46, 15, 84, 53, 20, 87, 48,  2,  6, 29, 28, 78, 43,
# ...

# %%
import numpy as np
# 1000 random integers b/w 0 and 50
q = np.random.randint(0,30,1000)
q
# Out:
# array([ 8, 28, 19,  9, 13,  3,  3, 16, 14, 23,  3, 27, 15,  4, 10,  0, 26,
#        13, 26, 15,  9,  1, 21, 11, 23, 10, 26, 16, 22, 21, 23, 26, 14,  7,
#        23,  5, 22, 15,  3, 23, 10, 27, 27,  2, 21,  8,  6, 15,  5, 27, 20,
#        25, 21,  6,  9,  4, 14, 28, 16,  2, 11, 20,  0,  4, 15, 14, 11,  3,
#         3, 19, 19, 15, 28,  2,  2, 14,  0, 10,  4, 17, 26, 19, 22, 29,  2,
#         6,  1, 25,  9, 24, 22, 19,  5, 18, 14, 19, 27, 25, 29,  2,  3, 14,
#        24,  6, 25, 16, 17, 17,  3, 28, 28, 14, 29,  6, 17, 14, 20, 17, 24,
#         9, 18,  4, 16,  3, 26, 13, 12, 16,  8, 28,  2, 21, 15,  2, 13, 26,
#         9, 10,  6, 20, 19, 16,  6,  4, 28, 16,  7, 16, 14,  1, 22,  6, 27,
#        15, 10, 11,  8,  5,  8, 13, 16, 12, 29, 10, 18,  8, 27,  3, 28, 14,
#         1, 23,  5, 19, 15, 11, 27,  2, 29, 27,  7,  6, 15, 21, 29, 18,  6,
#        24, 12, 14,  7, 15,  2, 12,  6, 15, 17,  5, 26, 22, 28, 13,  8,  7,
# ...

# %%
np.corrcoef(p,q)
# Out:
# array([[ 1.        , -0.02100394],
#        [-0.02100394,  1.        ]])

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use("ggplot")

plt.scatter(p,q)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint (0,50,1000)})
df['b'] = df['a'] + np.random.normal(0,100,1000) # positively correlated with a
df['c'] = 100-df['a'] + np.random.normal(0,5,1000) #negatively correlated with a
df['d'] = np.random.randint(0,50,1000) #not correlated with "a"
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.154669 -0.947577 -0.067437
# b  0.154669  1.000000 -0.136493 -0.002263
# c -0.947577 -0.136493  1.000000  0.061405
# d -0.067437 -0.002263  0.061405  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
